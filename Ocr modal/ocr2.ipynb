# %%
import cv2
import pytesseract
import glob

# Set the Tesseract path (Windows users)
# pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

image_files = sorted(glob.glob("page_*.jpg"))  # Sort ensures correct order

# Define separator
separator = "\n" + "=" * 50 + "\n"  # 50 equal signs for separation

# Store extracted text from all images
all_text = []

for image_path in image_files:
    try:
        print(f"Processing: {image_path}")
        img = cv2.imread(image_path)

        if img is None:
            print(f"Error: Could not read {image_path}")
            continue

        # Convert to grayscale (improves OCR accuracy)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Apply thresholding
        gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

        # Perform OCR
        text = pytesseract.image_to_string(gray)

        # Append result with file name
        all_text.append(f"Page: {image_path}\n{text}")

    except Exception as e:
        print(f"Error processing {image_path}: {e}")

# Combine all text with separator
final_output = separator.join(all_text)

# Save output to a file
with open("final_output.txt", "w", encoding="utf-8") as f:
    f.write(final_output)

# Print output
print("\nFinal Extracted Text:\n")
print(final_output)
# Out:
# Extracted Text :
#  PRACTICAL : 5
#
# Question: Create a HTML program to create a form as given below:
#
# Firstname: |
#
# Lastname:
#
# Course:{Course —v
#
# Gender:
#
# © Male
# O Female
# © Other
#
# Hobbies:
#
# © Programming
# O Cricket
#
# ©) Football
#
# ©) Reading Novel
#
# Phone: |
#
# Address
#
# Email: |
#
# Password: |
#
# | Submit || Reset |
#
# HTML Code :-
# <!DOCTYPE html>
# <html>
# <head>
# <title>Registration Form</title>
# </head>
# <body>
# <form>
# <label for="firstname">Firstname:</label>
#
# <input type="text" id="firstname" name="firstname" /><br /><br />
#
# <label for="lastname">Lastname:</label>
#
# <input type="text" id="lastname" name="lastname" /><br /><br />
#
# Name: Harshit Bhatt Section: B2 University Roll No: 2218816
